# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("VideoGamesSales.csv")

# %%
df2 = df[df.duplicated()]

# %%
df.shape
# Out:
# (5893, 15)

# %%
df = df.drop_duplicates()

# %%
df["Region"] = df["Region"].fillna("North")

# %%
df['Region'].isnull().shape
# Out:
# (5893,)
